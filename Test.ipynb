# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
import sys
import h5py

# %matplotlib inline

# %% [markdown]
# ### Validate training file

# %%
trainFilePath = 'data/train_surgery_tool.h5'

# %%
trainFile = h5py.File(trainFilePath, 'r');

# %%
list(trainFile.keys())
# Out:
# ['train_set_X', 'train_set_y']

# %%
sh = trainFile['train_set_X'].shape
sh
# Out:
# (23287, 224, 224, 3)

# %%
index = np.random.randint(sh[0]);
# index = 4
print(index);
x = trainFile['train_set_X'][index]
y = trainFile['train_set_y'][index]
x = x/255;    # normalize
print(y)
plt.imshow(x)
# Out:
# 22126
# [0 0 1 0 0 0 0]

# %% [markdown]
# # Test new data files

# %%
trainFilePath = 'data/train_dataset.h5'

# %%
trainFile = h5py.File(trainFilePath, 'r');
list(trainFile.keys())
# Out:
# ['train_img', 'train_label']

# %%
trainFile['train_img'].shape
# Out:
# (23287, 224, 224, 3)

# %%
trainFile['train_label'].shape
# Out:
# (23287, 7)

# %%
# index = np.random.randint(23287);
index = 78
print(index);
x = trainFile['train_img'][index]
y = trainFile['train_label'][index]
# x = x/255;    # normalize
print(y)
plt.imshow(x)
# Out:
# 78
# [1 0 0 0 0 0 0]

# %% [markdown]
# ## Test imports

# %%
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-152-64156d691fe5> in <module>()
# ----> 1 import tensorflow as tf
#
# ModuleNotFoundError: No module named 'tensorflow'
